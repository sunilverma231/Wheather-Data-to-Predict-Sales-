# %% [markdown]
# ### The data set contains weather data from Australia, and the same data is being used by an FMCG company to predict sales in their stores

# %%
#Improting the required Library 
import pandas as pd, numpy as np 
import matplotlib.pyplot as plt

# %%
# Loading the data using pandas
w_df = pd.read_csv("/Users/sunilverma/Downloads/New folder 3/weatherdata.csv")
w_df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed
# 0            NaN           W           44.0
# 1            NaN         WNW           44.0
# ...

# %%
w_df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed
# 0           W           44.0
# 1         WNW           44.0
# 2         WSW           46.0
# 3          NE           24.0
# 4           W           41.0

# %%
#checking the shape and size of the data 
w_df.shape
# Out:
# (142193, 9)

# %%
# find the days which has suhine for more than 4 hours, these days will have increased sales of sunscreen 
w_df[w_df["Sunshine"]>4]
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 5939    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 5940    2009-01-02    Cobar     18.4     28.9       0.0         14.8
# 5941    2009-01-03    Cobar     15.5     34.1       0.0         12.6
# 5942    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 5943    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# ...            ...      ...      ...      ...       ...          ...
# 139108  2017-06-20   Darwin     19.3     33.4       0.0          6.0
# 139109  2017-06-21   Darwin     21.2     32.6       0.0          7.6
# 139110  2017-06-22   Darwin     20.7     32.8       0.0          5.6
# 139111  2017-06-23   Darwin     19.5     31.8       0.0          6.2
# 139112  2017-06-24   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine WindGustDir  WindGustSpeed
# 5939        12.3         SSW           48.0
# 5940        13.0           S           37.0
# ...

# %%
#checking the unique values of Sunshine columns 
w_df["Sunshine"].unique()
# Out:
# array([ nan, 12.3, 13. , 13.3, 10.6, 12.2,  8.4,  0. , 12.6, 13.2, 12.7,
#        12.1, 10.3, 13.1, 12.9, 11.3,  6.9, 10.9,  3.7,  5.9, 10.5, 12.4,
#        13.4, 13.6,  7.4, 10. ,  2.3,  6.6,  0.3, 10.7, 11.6, 10.2,  9. ,
#        12. ,  3. ,  7.9, 11.5, 11.2,  4.8,  5.8,  6. , 11.1, 11.8, 11.4,
#        10.8,  7.8, 11. ,  5.5,  4.7,  4.2,  4.4,  6.2,  9.8,  9.9,  4.3,
#         8. ,  9.6, 10.4,  9.3,  8.7,  7.6,  7.5, 10.1,  6.3,  2.8,  0.7,
#         9.4,  9.7,  0.6,  5.1,  8.3,  4.1,  3.9,  6.8,  8.6,  2.7,  8.2,
#         3.1,  1.8,  0.1,  0.8,  3.4,  7.1,  5. ,  5.7,  6.1,  7. ,  2.9,
#         2.5,  4.6,  8.9,  9.1,  1.7,  8.1,  9.5,  1.2,  1.4,  8.8,  2.2,
#         3.5,  9.2,  1.9, 11.7, 11.9,  7.7,  0.9, 12.5,  2.1, 12.8, 13.7,
#         8.5,  0.2,  4. ,  2.4,  5.2,  0.5,  6.4,  4.5,  1.1,  2. ,  0.4,
#         1.5,  3.3,  6.5,  2.6,  3.8,  3.6,  3.2,  6.7,  5.4,  7.2,  4.9,
#         1. ,  1.6,  5.3,  7.3,  5.6,  1.3, 13.8, 13.5, 14. , 13.9, 14.1,
# ...

# %%
# filter the days having sunhine more then 4 hrs 
w_df[w_df["Sunshine"]>4]
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 5939    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 5940    2009-01-02    Cobar     18.4     28.9       0.0         14.8
# 5941    2009-01-03    Cobar     15.5     34.1       0.0         12.6
# 5942    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 5943    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# ...            ...      ...      ...      ...       ...          ...
# 139108  2017-06-20   Darwin     19.3     33.4       0.0          6.0
# 139109  2017-06-21   Darwin     21.2     32.6       0.0          7.6
# 139110  2017-06-22   Darwin     20.7     32.8       0.0          5.6
# 139111  2017-06-23   Darwin     19.5     31.8       0.0          6.2
# 139112  2017-06-24   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine WindGustDir  WindGustSpeed
# 5939        12.3         SSW           48.0
# 5940        13.0           S           37.0
# ...

# %%
# the cold drink sales will increase the days when days have high sunshine(>5) and high  max temprature(>35) 
w_df[(w_df["Sunshine"]>5) & (w_df["MaxTemp"]>35)]
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 5939    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 5942    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 5943    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# 5944    2009-01-06    Cobar     24.2     41.0       0.0         11.2
# 5948    2009-01-10    Cobar     19.0     35.5       0.0         12.0
# ...            ...      ...      ...      ...       ...          ...
# 138862  2016-10-17   Darwin     25.1     35.2       0.0          7.4
# 138879  2016-11-03   Darwin     24.4     35.5       0.0          7.8
# 138892  2016-11-16   Darwin     25.7     35.2       0.0          5.4
# 138905  2016-11-29   Darwin     25.8     35.1       0.8          4.8
# 138910  2016-12-04   Darwin     25.8     35.2       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed
# 5939        12.3         SSW           48.0
# 5942        10.6         NNE           46.0
# ...

# %%
#Making the new column as Year using DatetimeIndex 
w_df["Year"] = pd.DatetimeIndex(w_df["Date"]).year

# %%
w_df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  Year
# 0           W           44.0  2008
# 1         WNW           44.0  2008
# 2         WSW           46.0  2008
# 3          NE           24.0  2008
# 4           W           41.0  2008

# %%
# likewise making the new columns using the month and days 
w_df["Month"] = pd.DatetimeIndex(w_df["Date"]).month

# %%
w_df["Days of Month"] = pd.DatetimeIndex(w_df["Date"]).day

# %%
# Changeing the temprature from celcius to farenheight 
w_df["Max Temp F"] = round(w_df["MaxTemp"]*5/9+35,2)

# %%
w_df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  Year  Month  Days of Month  Max Temp F
# 0           W           44.0  2008     12              1       47.72
# 1         WNW           44.0  2008     12              2       48.94
# 2         WSW           46.0  2008     12              3       49.28
# 3          NE           24.0  2008     12              4       50.56
# 4           W           41.0  2008     12              5       52.94

# %%
# creating the lambda function to diffrenciate the values as Rainy or not rainy 
w_df["is_rainy"] = w_df.Rainfall.apply(lambda x: "Rainy" if x>50 else "Not Rainy")

# %%
w_df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  Year  Month  Days of Month  Max Temp F  \
# 0           W           44.0  2008     12              1       47.72
# 1         WNW           44.0  2008     12              2       48.94
# 2         WSW           46.0  2008     12              3       49.28
# 3          NE           24.0  2008     12              4       50.56
# 4           W           41.0  2008     12              5       52.94
#
#     is_rainy
# 0  Not Rainy
# 1  Not Rainy
# 2  Not Rainy
# 3  Not Rainy
# 4  Not Rainy

# %%
#checking the rainy values only 
w_df[w_df["is_rainy"]=="Rainy"]
# Out:
#               Date   Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 429     2010-02-05     Albury     19.2     26.1      52.2          NaN
# 455     2010-03-08     Albury     18.1     25.5      66.0          NaN
# 690     2010-10-31     Albury     13.8     18.7      50.8          NaN
# 704     2010-11-14     Albury     19.2     22.6      52.6          NaN
# 787     2011-02-05     Albury     20.4     23.0      99.2          NaN
# ...            ...        ...      ...      ...       ...          ...
# 140532  2017-02-03  Katherine     23.4     33.0      62.0          NaN
# 140571  2017-03-14  Katherine     23.0     35.0      79.0         31.0
# 140578  2017-03-22  Katherine     24.1     34.5      61.4          NaN
# 142013  2016-12-26      Uluru     22.1     27.4      83.8          NaN
# 142014  2016-12-27      Uluru     22.1     35.8      63.8          NaN
#
#         Sunshine WindGustDir  WindGustSpeed  Year  Month  Days of Month  \
# ...

# %%
# Hands on group by function 
data_by_location = w_df.groupby(by = ["Location"]).mean()
data_by_location.head()
# Out:
#                  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# Location
# Adelaide       12.628368  22.945402  1.572185     5.824924  7.752002
# Albany         12.948461  20.072587  2.255073     4.207273  6.658765
# Albury          9.520899  22.630963  1.925710          NaN       NaN
# AliceSprings   13.125182  29.244191  0.869355     9.029929  9.581944
# BadgerysCreek  11.136900  24.023111  2.207925          NaN       NaN
#
#                WindGustSpeed         Year     Month  Days of Month  Max Temp F
# Location
# Adelaide           36.530812  2012.525890  6.523948      15.740453   47.747529
# Albany                   NaN  2012.708554  6.413130      15.680371   46.151424
# Albury             32.953016  2012.733643  6.412488      15.745932   47.572721
# AliceSprings       40.533714  2012.719565  6.407456      15.689211   51.246795
# BadgerysCreek      33.609890  2012.790984  6.326161      15.769467   48.346226

# %%
# checking the most rainfall receiving area 
data_by_location.sort_values("Rainfall", ascending = False).head()
# Out:
#                 MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# Location
# Cairns        21.199197  29.544344  5.765317     6.211976  7.575995
# Darwin        23.210530  32.540977  5.094048     6.319089  8.499310
# CoffsHarbour  14.365774  23.915575  5.054592     3.904267  7.362374
# GoldCoast     17.341490  25.752971  3.728933          NaN       NaN
# Wollongong    14.949058  21.476510  3.589127          NaN       NaN
#
#               WindGustSpeed         Year     Month  Days of Month  Max Temp F
# Location
# Cairns            38.067991  2012.677376  6.363454      15.720214   51.413461
# Darwin            40.582355  2012.502820  6.534461      15.716792   53.078318
# CoffsHarbour      39.232197  2012.749746  6.392482      15.716898   48.286468
# GoldCoast         42.472539  2012.683221  6.435906      15.717114   49.307153
# Wollongong        45.695257  2012.743882  6.423734      15.694268   46.931359

# %% [markdown]
# #### Grouping and agrregating function
# Hot Choclates is the most sold product in the cold months. Find month is the coldest so that the inventory team can keep the inverntroy

# %%
# Grouping the data by Months 
data_bymonth = w_df.groupby(by = ["Month"]).mean()
data_bymonth.head()
# Out:
#          MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# Month
# 1      17.520778  29.547362  2.719036     8.773171  9.208942      43.361730
# 2      17.500239  28.877704  3.174075     7.651018  8.607494      41.457472
# 3      15.904347  26.886744  2.801304     6.237989  7.646279      39.546399
# 4      12.831979  23.611845  2.314764     4.547511  7.107208      36.460285
# 5       9.618572  20.047202  1.978896     3.244134  6.337496      35.721056
#
#               Year  Days of Month  Max Temp F
# Month
# 1      2013.042721      15.986688   51.415192
# 2      2013.054822      14.643515   51.043146
# 3      2013.024778      15.995321   49.937075
# 4      2013.279055      15.492659   48.117675
# 5      2013.040214      15.991038   46.137298

# %%
#Checking the place with MinTemp 

data_bymonth.sort_values("MinTemp").head()
# Out:
#         MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# Month
# 7      6.951308  16.764242  2.179314     2.699269  6.069790      37.891458
# 8      7.465145  18.258930  2.029610     3.616533  7.171661      40.245052
# 6      7.815031  17.324778  2.781114     2.518705  5.660379      35.506375
# 9      9.460189  20.772510  1.875851     4.917265  7.698770      42.213311
# 5      9.618572  20.047202  1.978896     3.244134  6.337496      35.721056
#
#               Year  Days of Month  Max Temp F         WCI
# Month
# 7      2012.467867      16.001528   44.313492  863.519699
# 8      2012.473474      16.022275   45.143861  836.501471
# 6      2012.975381      15.257648   44.624837  845.755217
# 9      2012.461084      15.518378   46.540286  762.816683
# 5      2013.040214      15.991038   46.137298  787.434259

# %%
data_bymonth.shape
# Out:
# (12, 9)

# %% [markdown]
# ### Grouping and aggregating function
# Sometimes feeling cold is more then about the low temprature;a windy can also make you cold, a factor called the chill factor can be used to quantify the cold based on the wind speed and the temp. the formula for the chill factor is given by
# WCI = (10* sqrt(v)-v+10.5)*(33-mintemp)
# v is the speed of the speed
# mintemp = minmum temprature
# add a column for WCI and find the month with the lowest WCI

# %%
# Creating the define function for WCI 
from math import sqrt 
def wci(x):
    velocity = x["WindGustSpeed"]
    minTemp = x["MinTemp"]
    return (10*sqrt(velocity)-velocity+10.5)*(33-minTemp)

# %%
# Applying the function to the dataset 
w_df["WCI"] = w_df.apply(wci, axis = 1)
w_df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  Year  Month  Days of Month  Max Temp F  \
# 0           W           44.0  2008     12              1       47.72
# 1         WNW           44.0  2008     12              2       48.94
# 2         WSW           46.0  2008     12              3       49.28
# 3          NE           24.0  2008     12              4       50.56
# 4           W           41.0  2008     12              5       52.94
#
#     is_rainy         WCI
# 0  Not Rainy  643.516918
# 1  Not Rainy  840.511893
# 2  Not Rainy  649.698327
# ...

# %%
data_bymonth = w_df.groupby(by = ["Month"]).mean()
data_bymonth
# Out:
#          MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# Month
# 1      17.520778  29.547362  2.719036     8.773171  9.208942      43.361730
# 2      17.500239  28.877704  3.174075     7.651018  8.607494      41.457472
# 3      15.904347  26.886744  2.801304     6.237989  7.646279      39.546399
# 4      12.831979  23.611845  2.314764     4.547511  7.107208      36.460285
# 5       9.618572  20.047202  1.978896     3.244134  6.337496      35.721056
# 6       7.815031  17.324778  2.781114     2.518705  5.660379      35.506375
# 7       6.951308  16.764242  2.179314     2.699269  6.069790      37.891458
# 8       7.465145  18.258930  2.029610     3.616533  7.171661      40.245052
# 9       9.460189  20.772510  1.875851     4.917265  7.698770      42.213311
# 10     11.531145  23.540695  1.610734     6.379571  8.500080      42.716694
# 11     14.299624  26.165571  2.273758     7.465236  8.685394      42.582385
# ...

# %%
#loadig the sales data 
june_sales = pd.read_csv("/Users/sunilverma/Downloads/New folder 2/junesales.csv", header = 0)
june_sales.head()
# Out:
#        Date  Tea_sales(in 100's)
# 0  6/1/2011                   26
# 1  6/2/2011                   35
# 2  6/3/2011                   37
# 3  6/4/2011                   33
# 4  6/5/2011                   25

# %%
#creating column by extracting the days of month from the dataset 
june_sales["Days of Month"] = pd.DatetimeIndex(june_sales["Date"]).day
june_sales.head()
# Out:
#        Date  Tea_sales(in 100's)  Days of Month
# 0  6/1/2011                   26              1
# 1  6/2/2011                   35              2
# 2  6/3/2011                   37              3
# 3  6/4/2011                   33              4
# 4  6/5/2011                   25              5

# %%
w_df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  Year  Month  Days of Month  Max Temp F  \
# 0           W           44.0  2008     12              1       47.72
# 1         WNW           44.0  2008     12              2       48.94
# 2         WSW           46.0  2008     12              3       49.28
# 3          NE           24.0  2008     12              4       50.56
# 4           W           41.0  2008     12              5       52.94
#
#     is_rainy         WCI
# 0  Not Rainy  643.516918
# 1  Not Rainy  840.511893
# 2  Not Rainy  649.698327
# ...

# %%
# Applying the condition to filter the date Location, Year and Month wise 
newcastle_data = w_df[(w_df["Location"]=="Newcastle")&(w_df["Year"]==2011) &(w_df["Month"]== 6)]
newcastle_data.head()
# Out:
#              Date   Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 15605  2011-06-01  Newcastle      NaN     21.2       6.0          NaN
# 15606  2011-06-02  Newcastle      NaN     20.2       4.0          NaN
# 15607  2011-06-03  Newcastle     10.7     20.2       0.4          NaN
# 15608  2011-06-04  Newcastle      9.4     20.4       0.0          NaN
# 15609  2011-06-05  Newcastle      9.6     18.8       3.0          NaN
#
#        Sunshine WindGustDir  WindGustSpeed  Year  Month  Days of Month  \
# 15605       NaN         NaN            NaN  2011      6              1
# 15606       NaN         NaN            NaN  2011      6              2
# 15607       NaN         NaN            NaN  2011      6              3
# 15608       NaN         NaN            NaN  2011      6              4
# 15609       NaN         NaN            NaN  2011      6              5
#
#        Max Temp F   is_rainy  WCI
# 15605       46.78  Not Rainy  NaN
# 15606       46.22  Not Rainy  NaN
# ...

# %%
# Merging the data on common column Days of Month
merge_data = newcastle_data.merge(w_df, on = "Days of Month")

# %%
#checking the columns 
merge_data.columns
# Out:
# Index(['Date_x', 'Location_x', 'MinTemp_x', 'MaxTemp_x', 'Rainfall_x',
#        'Evaporation_x', 'Sunshine_x', 'WindGustDir_x', 'WindGustSpeed_x',
#        'Year_x', 'Month_x', 'Days of Month', 'Max Temp F_x', 'is_rainy_x',
#        'WCI_x', 'Date_y', 'Location_y', 'MinTemp_y', 'MaxTemp_y', 'Rainfall_y',
#        'Evaporation_y', 'Sunshine_y', 'WindGustDir_y', 'WindGustSpeed_y',
#        'Year_y', 'Month_y', 'Max Temp F_y', 'is_rainy_y', 'WCI_y'],
#       dtype='object')

# %%
#loading the locationandstates data 
state_df = pd.read_csv("/Users/sunilverma/Downloads/New folder 3/locationsandstates.csv", header = 0)
state_df.head()
# Out:
#          Location             State
# 0          Sydney  New South Wales
# 1          Albury  New South Wales
# 2        Armidale  New South Wales
# 3        Bathurst  New South Wales
# 4  Blue Mountains  New South Wales

# %%
#Merging the data state data from 
state_data = w_df.merge(state_df, on = "Location", how = "left") 
state_data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  Year  Month  Days of Month  Max Temp F  \
# 0           W           44.0  2008     12              1       47.72
# 1         WNW           44.0  2008     12              2       48.94
# 2         WSW           46.0  2008     12              3       49.28
# 3          NE           24.0  2008     12              4       50.56
# 4           W           41.0  2008     12              5       52.94
#
#     is_rainy         WCI             State
# 0  Not Rainy  643.516918  New South Wales
# ...

# %%
# checking the data on Year[2016] basis 
data_2016 = w_df[w_df["Year"]== 2016]
data_2016.head()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 2474  2016-01-01   Albury     20.4     37.6       0.0          NaN       NaN
# 2475  2016-01-02   Albury     20.9     33.6       0.4          NaN       NaN
# 2476  2016-01-03   Albury     18.4     23.1       2.2          NaN       NaN
# 2477  2016-01-04   Albury     17.3     23.7      15.6          NaN       NaN
# 2478  2016-01-05   Albury     15.5     22.9       6.8          NaN       NaN
#
#      WindGustDir  WindGustSpeed  Year  Month  Days of Month  Max Temp F  \
# 2474         ENE           54.0  2016      1              1       55.89
# 2475         SSE           50.0  2016      1              2       53.67
# 2476         ENE           48.0  2016      1              3       47.83
# 2477         SSE           39.0  2016      1              4       48.17
# 2478         ENE           31.0  2016      1              5       47.72
#
#        is_rainy         WCI
# 2474  Not Rainy  377.807123
# ...

# %%
#applying the pivot table 
data_2016.pivot_table(index = "Location", columns ="Month", values = "Rainfall", aggfunc = "mean")
# Out:
# Month                    1         2          3         4         5   \
# Location
# Adelaide           1.703226  0.634483   1.735484  0.320000  2.838710
# Albany             2.380645  0.748276   1.144828  3.153333  3.158065
# Albury             2.206452  1.013793   0.961290  0.546667  3.477419
# AliceSprings       1.290323  0.910345   0.522581  0.000000  1.832258
# BadgerysCreek      5.012903  0.441379   1.019355  0.346667  0.380645
# Ballarat           1.358621  0.355556   1.180645  0.460000  2.303226
# Bendigo            1.117241  0.162963   1.077419  0.493333  2.677419
# Brisbane           0.972414  0.523077   3.787097  0.426667  0.890323
# Cairns             9.316129  4.689655   8.329032  4.593103  9.336842
# Canberra           3.432258  0.806897   0.916129  0.226667  1.535484
# Cobar              0.728571  0.062069   2.344828  1.313333  2.438710
# CoffsHarbour       3.129032  1.086207   2.345161  3.876667  0.112903
# ...
